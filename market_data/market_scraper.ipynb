# %% [markdown]
# ### An attempt in creating in automated market scraper for all current closed and open markets
# #### Multi-threaded event parser, (excluding MVE: sports parlays)

# %%
import requests

def get_clean_markets(status="open"):
    """Fetch single-leg markets only, excluding MVE combos."""
    base_url = "https://api.elections.kalshi.com/trade-api/v2/markets"
    all_markets = []
    cursor = None
    
    while True:
        params = {
            "limit": 1000,
            "status": status,
            "mve_filter": "exclude"  # Filter out multivariate/parlay markets
        }
        if cursor:
            params["cursor"] = cursor
            
        response = requests.get(base_url, params=params)
        data = response.json()
        
        markets = data.get("markets", [])
        all_markets.extend(markets)
        
        cursor = data.get("cursor")
        if not cursor or not markets:
            break
    
    return all_markets

markets = get_clean_markets("open")

# Now titles should be clean
for m in markets[:1000]:
    print(f"{m['ticker']}: {m['title']}")
# Out:
# KXTABLETENNIS-26FEB111630BSUMPI-MPI: Will Milosz Piecowski win the Bartek Sulkowski vs Milosz Piecowski Table Tennis Match Winner?
# KXTABLETENNIS-26FEB111630BSUMPI-BSU: Will Bartek Sulkowski win the Bartek Sulkowski vs Milosz Piecowski Table Tennis Match Winner?
# KXPSAKIMENTION-26FEB12-VICT: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-TRUM: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-REDA: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-PAM: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-KASH: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-INVE: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-HOWA: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-GHIS: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-EPST: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXPSAKIMENTION-26FEB12-CORR: What will Jamie Raskin say during The Briefing With Jen Psaki?
# KXATPMATCH-26FEB12MEDAUG-MED: Will Hamad Medjedovic win the Medjedovic vs Auger-Aliassime : Round Of 16 match?
# KXATPMATCH-26FEB12MEDAUG-AUG: Will Felix Auger-Aliassime win the Medjedovic vs Auger-Aliassime : Round Of 16 match?
# KXTABLETENNIS-26FEB111620ZNOPPO-ZNO: Will Zbigniew Nocun win the Zbigniew Nocun vs Pawel Polanski Table Tennis Match Winner?
# KXTABLETENNIS-26FEB111620ZNOPPO-PPO: Will Pawel Polanski win the Zbigniew Nocun vs Pawel Polanski Table Tennis Match Winner?
# KXBILLBOARDRUNNERUPALBUM-26FEB21-FAL: Billboard 200 #2 on Feb 21, 2026 chart?
# KXTOPALBUM-26FEB21-FAL: Billboard Top 200 #1 on Feb 21, 2026 chart?
# KXATPMATCH-26FEB12QUICIL-QUI: Will Ethan Quinn win the Quinn vs Cilic : Round Of 16 match?
# KXATPMATCH-26FEB12QUICIL-CIL: Will Marin Cilic win the Quinn vs Cilic : Round Of 16 match?
# KXTABLETENNIS-26FEB111605FKUMSI-MSI: Will Maciej Sinicki win the Filip Kujawa vs Maciej Sinicki Table Tennis Match Winner?
# KXTABLETENNIS-26FEB
at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.197: Will the EUR/USD open price be between 1.19600 and 1.19799 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.195: Will the EUR/USD open price be between 1.19400 and 1.19599 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.193: Will the EUR/USD open price be between 1.19200 and 1.19399 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.191: Will the EUR/USD open price be between 1.19000 and 1.19199 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.189: Will the EUR/USD open price be between 1.18800 and 1.18999 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.187: Will the EUR/USD open price be between 1.18600 and 1.18799 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.185: Will the EUR/USD open price be between 1.18400 and 1.18599 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.183: Will the EUR/USD open price be between 1.18200 and 1.18399 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.181: Will the EUR/USD open price be between 1.18000 and 1.18199 at Feb 12, 2026 at 10am EST?
# KXEURUSD-26FEB1210-B1.179: Will the EUR/USD open price be between 1.17800 and 1.17999 at Feb 12, 2026 at 10am EST?
# KXBILLBOARDRUNNERUPSONG-26FEB28-THEF: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-THE: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-ORD: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-MAN: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-IJU: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-GOL: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-FOL: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-DTM: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-CHO: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXBILLBOARDRUNNERUPSONG-26FEB28-BAC: Billboard Hot 100 #2 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-WIT: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-THEL: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-THE: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-STI: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-SOS: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-OCT: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-KPO: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-IMT: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-DON: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPALBUM-26FEB28-DEB: Billboard Top 200 #1 on Feb 28, 2026 chart?
# KXTOPSONG-26FEB28-THEF: Will The Fate Of Ophelia be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-THE: Will The Great Divide be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-ORD: Will Ordinary be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-MAN: Will Man I Need be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-IJU: Will I Just Might be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-GOL: Will Golden be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-FOL: Will Folded be the #1 song on the Billboard Hot 100 charts this week?
# KXTOPSONG-26FEB28-DTM: Will DTMF be the #1 song on the Billboard Hot 100 charts this week?
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

BASE_URL = "https://api.elections.kalshi.com/trade-api/v2/events"

def get_session() -> requests.Session:
    """Create a session with retry logic."""
    session = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.5,
        status_forcelist=[429, 500, 502, 503, 504]
    )
    adapter = HTTPAdapter(max_retries=retries)
    session.mount("https://", adapter)
    return session

def fetch_events_page(session: requests.Session, status: str = None, cursor: str = None) -> dict:
    """Fetch a single page of events."""
    params = {"limit": 200}  # Events API max is likely 200, not 1000
    if status:
        params["status"] = status
    if cursor:
        params["cursor"] = cursor
    
    response = session.get(BASE_URL, params=params, timeout=30)
    response.raise_for_status()
    return response.json()

def fetch_all_events_for_status(status: str = None) -> list:
    """Fetch all events for a given status (handles pagination). If status is None, fetches all."""
    session = get_session()
    all_events = []
    cursor = None
    page = 0
    label = status if status else "all"
    
    while True:
        page += 1
        data = fetch_events_page(session, status, cursor)
        events = data.get("events", [])
        
        if not events:
            break
            
        # Add status to each event for tracking
        for event in events:
            event["scrape_status"] = label
        
        all_events.extend(events)
        print(f"  [{label}] Page {page}: fetched {len(events)} events (total: {len(all_events)})")
        
        cursor = data.get("cursor")
        if not cursor:
            break
        
        # Small delay to be nice to the API
        time.sleep(0.1)
    
    return all_events

def scrape_all_events() -> list:
    """Scrape all events using multi-threading for different statuses."""
    statuses = ["open", "closed", "settled"]
    all_events = []
    
    print(f"Starting scrape at {datetime.now().isoformat()}")
    print("-" * 50)
    
    # First try with status filters in parallel
    with ThreadPoolExecutor(max_workers=3) as executor:
        future_to_status = {
            executor.submit(fetch_all_events_for_status, status): status 
            for status in statuses
        }
        
        for future in as_completed(future_to_status):
            status = future_to_status[future]
            try:
                events = future.result()
                all_events.extend(events)
                print(f"  [{status}] Complete: {len(events)} events")
            except Exception as e:
                print(f"  [{status}] Error: {e}")
    
    # If status filters failed, try fetching all without filter
    if len(all_events) == 0:
        print("\nStatus filters failed. Trying without status filter...")
        try:
            all_events = fetch_all_events_for_status(None)
            print(f"  [all] Complete: {len(all_events)} events")
        except Exception as e:
            print(f"  [all] Error: {e}")
    
    print("-" * 50)
    print(f"Total events scraped: {len(all_events)}")
    
    return all_events

def events_to_csv(events: list, filename: str):
    """Save events to CSV file."""
    if not events:
        print("No events to save.")
        return
    
    # Define columns to extract
    columns = [
        "event_ticker",
        "series_ticker", 
        "title",
        "sub_title",
        "category",
        "mutually_exclusive",
        "available_on_brokers",
        "collateral_return_type",
        "strike_period",
        "scrape_status"
    ]
    
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=columns, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(events)
    
    print(f"Saved {len(events)} events to {filename}")

def main():
    # Scrape all events
    events = scrape_all_events()
    
    # Save to CSV with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"kalshi_events_{timestamp}.csv"
    events_to_csv(events, filename)
    
    # Print summary by category
    print("\n" + "=" * 50)
    print("SUMMARY BY CATEGORY")
    print("=" * 50)
    
    categories = {}
    for event in events:
        cat = event.get("category", "Unknown")
        categories[cat] = categories.get(cat, 0) + 1
    
    for cat, count in sorted(categories.items(), key=lambda x: -x[1]):
        print(f"  {cat}: {count}")
    
    # Print summary by status
    print("\n" + "=" * 50)
    print("SUMMARY BY STATUS")
    print("=" * 50)
    
    statuses = {}
    for event in events:
        status = event.get("scrape_status", "Unknown")
        statuses[status] = statuses.get(status, 0) + 1
    
    for status, count in sorted(statuses.items(), key=lambda x: -x[1]):
        print(f"  {status}: {count}")
    
    return filename

if __name__ == "__main__":
    output_file = main()
    print(f"\nDone! Output: {output_file}")
# Out:
# Starting scrape at 2026-02-10T19:54:30.253911
# --------------------------------------------------
#   [open] Page 1: fetched 200 events (total: 200)
#   [settled] Page 1: fetched 200 events (total: 200)
#   [closed] Page 1: fetched 200 events (total: 200)
#   [open] Page 2: fetched 200 events (total: 400)
#   [open] Page 3: fetched 200 events (total: 600)
#   [settled] Page 2: fetched 200 events (total: 400)
#   [closed] Page 2: fetched 200 events (total: 400)
#   [settled] Page 3: fetched 200 events (total: 600)
#   [closed] Page 3: fetched 53 events (total: 453)
#   [closed] Complete: 453 events
#   [settled] Page 4: fetched 200 events (total: 800)
#   [settled] Page 5: fetched 200 events (total: 1000)
#   [settled] Page 6: fetched 200 events (total: 1200)
#   [settled] Page 7: fetched 200 events (total: 1400)
#   [open] Page 4: fetched 200 events (total: 800)
#   [settled] Page 8: fetched 200 events (total: 1600)
#   [open] Page 5: fetched 200 events (total: 1000)
#   [settled] Page 9: fetched 200 events (total: 1800)
#   [open] Page 6: fetched 200 events (total: 1200)
#   [open] Page 7: fetched 200 events (total: 1400)
#   [settled] Page 10: fetched 200 events (total: 2000)
#   [settled] Page 11: fetched 200 events (total: 2200)
#   [open] Page 8: fetched 200 events (total: 1600)
#   [settled] Page 12: fetched 200 events (total: 2400)
#   [open] Page 9: fetched 200 events (total: 1800)
#   [open] Page 10: fetched 200 events (total: 2000)
#   [settled] Page 13: fetched 200 events (total: 2600)
#   [settled] Page 14: fetched 200 events (total: 2800)
#   [open] Page 11: fetched 200 events (total: 2200)
#   [settled] Page 15: fetched 200 events (total: 3000)
#   [open] Page 12: fetched 200 events (total: 2400)
#   [open] Page 13: fetched 200 events (total: 2600)
#   [settled] Page 16: fetched 200 events (total: 3200)
#   [settled] Page 17: fetched 200 events (total: 3400)
#   [open] Page 14: fetched 200 events (total: 2800)
#   [settled] Page 18: fetched 200 events (total: 3600)
#   [open] Page 15: fetched 200 events (total: 3000)
#   [settled] Page 19: fetched 200 events (total: 3800)
#   [open] Page 16: fetched 200 events (total: 3200)
#   [settled] Page 20: fetched 200 events (total: 4000)
#   [open] Page 17: fetched 200 events (total: 3400)
#   [settled] Page 21: fetched 200 events (total: 4200)
#   [open] Page 18: fetched 200 events (total: 3600)
#   [settled] Page 22: fetched 200 events (total: 4400)
#   [settled] Page 23: fetched 200 events (total: 4600)
#   [open] Page 19: fetched 200 events (total: 3800)
#   [settled] Page 24: fetched 200 events (total: 4800)
#   [open] Page 20: fetched 200 events (total: 4000)
#   [settled] Page 25: fetched 200 events (total: 5000)
#   [open] Page 21: fetched 132 events (total: 4132)
#   [open] Complete: 4132 events
#   [settled] Page 26: fetched 200 events (total: 5200)
#   [settled] Page 27: fetched 200 events (total: 5400)
#   [settled] Page 28: fetched 200 events (total: 5600)
#   [settled] Page 29: fetched 200 events (total: 5800)
#   [settled] Page 30: fetched 200 events (total: 6000)
#   [settled] Page 31: fetched 200 events (total: 6200)
#   [settled] Page 32: fetched 200 events (total: 6400)
#   [settled] Page 33: fetched 200 events (total: 6600)
#   [settled] Page 34: fetched 200 events (total: 6800)
#   [settled] Page 35: fetched 200 events (total: 7000)
#   [settled] Page 36: fetched 200 events (total: 7200)
#   [settled] Page 37: fetched 200 events (total: 7400)
#   [settled] Page 38: fetched 200 events (total: 7600)
#   [settled] Page 39: fetched 200 events (total: 7800)
#   [settled] Page 40: fetched 200 events (total: 8000)
#   [settled] Page 41: fetched 200 events (total: 8200)
#   [settled] Page 42: fetched 200 events (total: 8400)
#   [settled] Page 43: fetched 200 events (total: 8600)
#   [settled] Page 44: fetched 200 events (total: 8800)
#   [settled] Page 45: fetched 200 events (total: 9000)
#   [settled] Page 46: fetched 200 events (total: 9200)
#   [settled] Page 47: fetched 200 events (total: 9400)
#   [settled] Page 48: fetched 200 events (total: 9600)
#   [settled] Page 49: fetched 200 events (total: 9800)
#   [settled] Page 50: fetched 200 events (total: 10000)
#   [settled] Page 51: fetched 200 events (total: 10200)
#   [settled] Page 52: fetched 200 events (total: 10400)
#   [settled] Page 53: fetched 200 events (total: 10600)
#   [settled] Page 54: fetched 200 events (total: 10800)
#   [settled] Page 55: fetched 200 events (total: 11000)
#   [settled] Page 56: fetched 200 events (total: 11200)
#   [settled] Page 57: fetched 200 events (total: 11400)
#   [settled] Page 58: fetched 200 events (total: 11600)
#   [settled] Page 59: fetched 200 events (total: 11800)
#   [settled] Page 60: fetched 200 events (total: 12000)
#   [settled] Page 61: fetched 200 events (total: 12200)
#   [settled] Page 62: fetched 200 events (total: 12400)
#   [settled] Page 63: fetched 200 events (total: 12600)
#   [settled] Page 64: fetched 200 events (total: 12800)
#   [settled] Page 65: fetched 200 events (total: 13000)
#   [settled] Page 66: fetched 200 events (total: 13200)
#   [settled] Page 67: fetched 200 events (total: 13400)
#   [settled] Page 68: fetched 200 events (total: 13600)
#   [settled] Page 69: fetched 200 events (total: 13800)
#   [settled] Page 70: fetched 200 events (total: 14000)
#   [settled] Page 71: fetched 200 events (total: 14200)
#   [settled] Page 72: fetched 200 events (total: 14400)
#   [settled] Page 73: fetched 200 events (total: 14600)
#   [settled] Page 74: fetched 200 events (total: 14800)
#   [settled] Page 75: fetched 200 events (total: 15000)
#   [settled] Page 76: fetched 200 events (total: 15200)
#   [settled] Page 77: fetched 200 events (total: 15400)
#   [settled] Page 78: fetched 200 events (total: 15600)
#   [settled] Page 79: fetched 200 events (total: 15800)
#   [settled] Page 80: fetched 200 events (total: 16000)
#   [settled] Page 81: fetched 200 events (total: 16200)
#   [settled] Page 82: fetched 200 events (total: 16400)
#   [settled] Page 83: fetched 200 events (total: 16600)
#   [settled] Page 84: fetched 200 events (total: 16800)
#   [settled] Page 85: fetched 200 events (total: 17000)
#   [settled] Page 86: fetched 200 events (total: 17200)
#   [settled] Page 87: fetched 200 events (total: 17400)
#   [settled] Page 88: fetched 200 events (total: 17600)
#   [settled] Page 89: fetched 200 events (total: 17800)
#   [settled] Page 90: fetched 200 events (total: 18000)
#   [settled] Page 91: fetched 200 events (total: 18200)
#   [settled] Page 92: fetched 200 events (total: 18400)
#   [settled] Page 93: fetched 200 events (total: 18600)
#   [settled] Page 94: fetched 200 events (total: 18800)
#   [settled] Page 95: fetched 200 events (total: 19000)
#   [settled] Page 96: fetched 200 events (total: 19200)
#   [settled] Page 97: fetched 200 events (total: 19400)
#   [settled] Page 98: fetched 200 events (total: 19600)
#   [settled] Page 99: fetched 200 events (total: 19800)
#   [settled] Page 100: fetched 200 events (total: 20000)
#   [settled] Page 101: fetched 200 events (total: 20200)
#   [settled] Page 102: fetched 200 events (total: 20400)
#   [settled] Page 103: fetched 200 events (total: 20600)
#   [settled] Page 104: fetched 200 events (total: 20800)
#   [settled] Page 105: fetched 200 events (total: 21000)
#   [settled] Page 106: fetched 200 events (total: 21200)
#   [settled] Page 107: fetched 200 events (total: 21400)
#   [settled] Page 108: fetched 200 events (total: 21600)
#   [settled] Page 109: fetched 200 events (total: 21800)
#   [settled] Page 110: fetched 200 events (total: 22000)
#   [settled] Page 111: fetched 200 events (total: 22200)
#   [settled] Page 112: fetched 200 events (total: 22400)
#   [settled] Page 113: fetched 200 events (total: 22600)
#   [settled] Page 114: fetched 200 events (total: 22800)
#   [settled] Page 115: fetched 200 events (total: 23000)
#   [settled] Page 116: fetched 200 events (total: 23200)
#   [settled] Page 117: fetched 200 events (total: 23400)
#   [settled] Page 118: fetched 200 events (total: 23600)
#   [settled] Page 119: fetched 200 events (total: 23800)
#   [settled] Page 120: fetched 200 events (total: 24000)
#   [settled] Page 121: fetched 200 events (total: 24200)
#   [settled] Page 122: fetched 200 events (total: 24400)
#   [settled] Page 123: fetched 200 events (total: 24600)
#   [settled] Page 124: fetched 200 events (total: 24800)
#   [settled] Page 125: fetched 200 events (total: 25000)
#   [settled] Page 126: fetched 200 events (total: 25200)
#   [settled] Page 127: fetched 200 events (total: 25400)
#   [settled] Page 128: fetched 200 events (total: 25600)
#   [settled] Page 129: fetched 200 events (total: 25800)
#   [settled] Page 130: fetched 200 events (total: 26000)
#   [settled] Page 131: fetched 200 events (total: 26200)
#   [settled] Page 132: fetched 200 events (total: 26400)
#   [settled] Page 133: fetched 200 events (total: 26600)
#   [settled] Page 134: fetched 200 events (total: 26800)
#   [settled] Page 135: fetched 200 events (total: 27000)
#   [settled] Page 136: fetched 200 events (total: 27200)
#   [settled] Page 137: fetched 200 events (total: 27400)
#   [settled] Page 138: fetched 200 events (total: 27600)
#   [settled] Page 139: fetched 200 events (total: 27800)
#   [settled] Page 140: fetched 200 events (total: 28000)
#   [settled] Page 141: fetched 200 events (total: 28200)
#   [settled] Page 142: fetched 200 events (total: 28400)
#   [settled] Page 143: fetched 200 events (total: 28600)
#   [settled] Page 144: fetched 200 events (total: 28800)
#   [settled] Page 145: fetched 200 events (total: 29000)
#   [settled] Page 146: fetched 200 events (total: 29200)
#   [settled] Page 147: fetched 200 events (total: 29400)
#   [settled] Page 148: fetched 200 events (total: 29600)
#   [settled] Page 149: fetched 200 events (total: 29800)
#   [settled] Page 150: fetched 200 events (total: 30000)
#   [settled] Page 151: fetched 200 events (total: 30200)
#   [settled] Page 152: fetched 200 events (total: 30400)
#   [settled] Page 153: fetched 200 events (total: 30600)
#   [settled] Page 154: fetched 200 events (total: 30800)
#   [settled] Page 155: fetched 200 events (total: 31000)
#   [settled] Page 156: fetched 200 events (total: 31200)
#   [settled] Page 157: fetched 200 events (total: 31400)
#   [settled] Page 158: fetched 200 events (total: 31600)
#   [settled] Page 159: fetched 200 events (total: 31800)
#   [settled] Page 160: fetched 200 events (total: 32000)
#   [settled] Page 161: fetched 200 events (total: 32200)
#   [settled] Page 162: fetched 200 events (total: 32400)
#   [settled] Page 163: fetched 200 events (total: 32600)
#   [settled] Page 164: fetched 200 events (total: 32800)
#   [settled] Page 165: fetched 200 events (total: 33000)
#   [settled] Page 166: fetched 200 events (total: 33200)
#   [settled] Page 167: fetched 200 events (total: 33400)
#   [settled] Page 168: fetched 200 events (total: 33600)
#   [settled] Page 169: fetched 200 events (total: 33800)
#   [settled] Page 170: fetched 200 events (total: 34000)
#   [settled] Page 171: fetched 200 events (total: 34200)
#   [settled] Page 172: fetched 200 events (total: 34400)
#   [settled] Page 173: fetched 200 events (total: 34600)
#   [settled] Page 174: fetched 200 events (total: 34800)
#   [settled] Page 175: fetched 200 events (total: 35000)
#   [settled] Page 176: fetched 200 events (total: 35200)
#   [settled] Page 177: fetched 200 events (total: 35400)
#   [settled] Page 178: fetched 200 events (total: 35600)
#   [settled] Page 179: fetched 200 events (total: 35800)
#   [settled] Page 180: fetched 200 events (total: 36000)
#   [settled] Page 181: fetched 200 events (total: 36200)
#   [settled] Page 182: fetched 200 events (total: 36400)
#   [settled] Page 183: fetched 200 events (total: 36600)
#   [settled] Page 184: fetched 200 events (total: 36800)
#   [settled] Page 185: fetched 200 events (total: 37000)
#   [settled] Page 186: fetched 200 events (total: 37200)
#   [settled] Page 187: fetched 200 events (total: 37400)
#   [settled] Page 188: fetched 200 events (total: 37600)
#   [settled] Page 189: fetched 200 events (total: 37800)
#   [settled] Page 190: fetched 200 events (total: 38000)
#   [settled] Page 191: fetched 200 events (total: 38200)
#   [settled] Page 192: fetched 200 events (total: 38400)
#   [settled] Page 193: fetched 200 events (total: 38600)
#   [settled] Page 194: fetched 200 events (total: 38800)
#   [settled] Page 195: fetched 200 events (total: 39000)
#   [settled] Page 196: fetched 200 events (total: 39200)
#   [settled] Page 197: fetched 200 events (total: 39400)
#   [settled] Page 198: fetched 200 events (total: 39600)
#   [settled] Page 199: fetched 200 events (total: 39800)
#   [settled] Page 200: fetched 200 events (total: 40000)
#   [settled] Page 201: fetched 200 events (total: 40200)
#   [settled] Page 202: fetched 200 events (total: 40400)
#   [settled] Page 203: fetched 200 events (total: 40600)
#   [settled] Page 204: fetched 200 events (total: 40800)
#   [settled] Page 205: fetched 200 events (total: 41000)
#   [settled] Page 206: fetched 200 events (total: 41200)
#   [settled] Page 207: fetched 200 events (total: 41400)
#   [settled] Page 208: fetched 200 events (total: 41600)
#   [settled] Page 209: fetched 200 events (total: 41800)
#   [settled] Page 210: fetched 200 events (total: 42000)
#   [settled] Page 211: fetched 200 events (total: 42200)
#   [settled] Page 212: fetched 200 events (total: 42400)
#   [settled] Page 213: fetched 200 events (total: 42600)
#   [settled] Page 214: fetched 200 events (total: 42800)
#   [settled] Page 215: fetched 200 events (total: 43000)
#   [settled] Page 216: fetched 200 events (total: 43200)
#   [settled] Page 217: fetched 200 events (total: 43400)
#   [settled] Page 218: fetched 200 events (total: 43600)
#   [settled] Page 219: fetched 200 events (total: 43800)
#   [settled] Page 220: fetched 200 events (total: 44000)
#   [settled] Page 221: fetched 200 events (total: 44200)
#   [settled] Page 222: fetched 200 events (total: 44400)
#   [settled] Page 223: fetched 200 events (total: 44600)
#   [settled] Page 224: fetched 200 events (total: 44800)
#   [settled] Page 225: fetched 200 events (total: 45000)
#   [settled] Page 226: fetched 200 events (total: 45200)
#   [settled] Page 227: fetched 200 events (total: 45400)
#   [settled] Page 228: fetched 200 events (total: 45600)
#   [settled] Page 229: fetched 200 events (total: 45800)
#   [settled] Page 230: fetched 200 events (total: 46000)
#   [settled] Page 231: fetched 200 events (total: 46200)
#   [settled] Page 232: fetched 200 events (total: 46400)
#   [settled] Page 233: fetched 200 events (total: 46600)
#   [settled] Page 234: fetched 200 events (total: 46800)
#   [settled] Page 235: fetched 200 events (total: 47000)
#   [settled] Page 236: fetched 200 events (total: 47200)
#   [settled] Page 237: fetched 200 events (total: 47400)
#   [settled] Page 238: fetched 200 events (total: 47600)
#   [settled] Page 239: fetched 200 events (total: 47800)
#   [settled] Page 240: fetched 200 events (total: 48000)
#   [settled] Page 241: fetched 200 events (total: 48200)
#   [settled] Page 242: fetched 200 events (total: 48400)
#   [settled] Page 243: fetched 200 events (total: 48600)
#   [settled] Page 244: fetched 200 events (total: 48800)
#   [settled] Page 245: fetched 200 events (total: 49000)
#   [settled] Page 246: fetched 200 events (total: 49200)
#   [settled] Page 247: fetched 200 events (total: 49400)
#   [settled] Page 248: fetched 200 events (total: 49600)
#   [settled] Page 249: fetched 200 events (total: 49800)
#   [settled] Page 250: fetched 200 events (total: 50000)
#   [settled] Page 251: fetched 200 events (total: 50200)
#   [settled] Page 252: fetched 200 events (total: 50400)
#   [settled] Page 253: fetched 200 events (total: 50600)
#   [settled] Page 254: fetched 200 events (total: 50800)
#   [settled] Page 255: fetched 200 events (total: 51000)
#   [settled] Page 256: fetched 200 events (total: 51200)
#   [settled] Page 257: fetched 200 events (total: 51400)
#   [settled] Page 258: fetched 200 events (total: 51600)
#   [settled] Page 259: fetched 200 events (total: 51800)
#   [settled] Page 260: fetched 200 events (total: 52000)
#   [settled] Page 261: fetched 200 events (total: 52200)
#   [settled] Page 262: fetched 200 events (total: 52400)
#   [settled] Page 263: fetched 200 events (total: 52600)
#   [settled] Page 264: fetched 200 events (total: 52800)
#   [settled] Page 265: fetched 200 events (total: 53000)
#   [settled] Page 266: fetched 200 events (total: 53200)
#   [settled] Page 267: fetched 200 events (total: 53400)
#   [settled] Page 268: fetched 200 events (total: 53600)
#   [settled] Page 269: fetched 200 events (total: 53800)
#   [settled] Page 270: fetched 200 events (total: 54000)
#   [settled] Page 271: fetched 200 events (total: 54200)
#   [settled] Page 272: fetched 200 events (total: 54400)
#   [settled] Page 273: fetched 200 events (total: 54600)
#   [settled] Page 274: fetched 200 events (total: 54800)
#   [settled] Page 275: fetched 200 events (total: 55000)
#   [settled] Page 276: fetched 200 events (total: 55200)
#   [settled] Page 277: fetched 200 events (total: 55400)
#   [settled] Page 278: fetched 200 events (total: 55600)
#   [settled] Page 279: fetched 200 events (total: 55800)
#   [settled] Page 280: fetched 200 events (total: 56000)
#   [settled] Page 281: fetched 200 events (total: 56200)
#   [settled] Page 282: fetched 200 events (total: 56400)
#   [settled] Page 283: fetched 200 events (total: 56600)
#   [settled] Page 284: fetched 200 events (total: 56800)
#   [settled] Page 285: fetched 200 events (total: 57000)
#   [settled] Page 286: fetched 200 events (total: 57200)
#   [settled] Page 287: fetched 200 events (total: 57400)
#   [settled] Page 288: fetched 200 events (total: 57600)
#   [settled] Page 289: fetched 200 events (total: 57800)
#   [settled] Page 290: fetched 200 events (total: 58000)
#   [settled] Page 291: fetched 200 events (total: 58200)
#   [settled] Page 292: fetched 200 events (total: 58400)
#   [settled] Page 293: fetched 200 events (total: 58600)
#   [settled] Page 294: fetched 200 events (total: 58800)
#   [settled] Page 295: fetched 200 events (total: 59000)
#   [settled] Page 296: fetched 200 events (total: 59200)
#   [settled] Page 297: fetched 200 events (total: 59400)
#   [settled] Page 298: fetched 200 events (total: 59600)
#   [settled] Page 299: fetched 200 events (total: 59800)
#   [settled] Page 300: fetched 200 events (total: 60000)
#   [settled] Page 301: fetched 200 events (total: 60200)
#   [settled] Page 302: fetched 200 events (total: 60400)
#   [settled] Page 303: fetched 200 events (total: 60600)
#   [settled] Page 304: fetched 200 events (total: 60800)
#   [settled] Page 305: fetched 200 events (total: 61000)
#   [settled] Page 306: fetched 200 events (total: 61200)
#   [settled] Page 307: fetched 200 events (total: 61400)
#   [settled] Page 308: fetched 200 events (total: 61600)
#   [settled] Page 309: fetched 200 events (total: 61800)
#   [settled] Page 310: fetched 200 events (total: 62000)
#   [settled] Page 311: fetched 200 events (total: 62200)
#   [settled] Page 312: fetched 200 events (total: 62400)
#   [settled] Page 313: fetched 200 events (total: 62600)
#   [settled] Page 314: fetched 200 events (total: 62800)
#   [settled] Page 315: fetched 200 events (total: 63000)
#   [settled] Page 316: fetched 200 events (total: 63200)
#   [settled] Page 317: fetched 200 events (total: 63400)
#   [settled] Page 318: fetched 200 events (total: 63600)
#   [settled] Page 319: fetched 200 events (total: 63800)
#   [settled] Page 320: fetched 200 events (total: 64000)
#   [settled] Page 321: fetched 200 events (total: 64200)
#   [settled] Page 322: fetched 200 events (total: 64400)
#   [settled] Page 323: fetched 200 events (total: 64600)
#   [settled] Page 324: fetched 200 events (total: 64800)
#   [settled] Page 325: fetched 200 events (total: 65000)
#   [settled] Page 326: fetched 200 events (total: 65200)
#   [settled] Page 327: fetched 200 events (total: 65400)
#   [settled] Page 328: fetched 200 events (total: 65600)
#   [settled] Page 329: fetched 200 events (total: 65800)
#   [settled] Page 330: fetched 200 events (total: 66000)
#   [settled] Page 331: fetched 200 events (total: 66200)
#   [settled] Page 332: fetched 200 events (total: 66400)
#   [settled] Page 333: fetched 200 events (total: 66600)
#   [settled] Page 334: fetched 200 events (total: 66800)
#   [settled] Page 335: fetched 200 events (total: 67000)
#   [settled] Page 336: fetched 200 events (total: 67200)
#   [settled] Page 337: fetched 200 events (total: 67400)
#   [settled] Page 338: fetched 200 events (total: 67600)
#   [settled] Page 339: fetched 200 events (total: 67800)
#   [settled] Page 340: fetched 200 events (total: 68000)
#   [settled] Page 341: fetched 200 events (total: 68200)
#   [settled] Page 342: fetched 200 events (total: 68400)
#   [settled] Page 343: fetched 200 events (total: 68600)
#   [settled] Page 344: fetched 200 events (total: 68800)
#   [settled] Page 345: fetched 200 events (total: 69000)
#   [settled] Page 346: fetched 200 events (total: 69200)
#   [settled] Page 347: fetched 200 events (total: 69400)
#   [settled] Page 348: fetched 200 events (total: 69600)
#   [settled] Page 349: fetched 200 events (total: 69800)
#   [settled] Page 350: fetched 200 events (total: 70000)
#   [settled] Page 351: fetched 200 events (total: 70200)
#   [settled] Page 352: fetched 200 events (total: 70400)
#   [settled] Page 353: fetched 200 events (total: 70600)
#   [settled] Page 354: fetched 200 events (total: 70800)
#   [settled] Page 355: fetched 200 events (total: 71000)
#   [settled] Page 356: fetched 200 events (total: 71200)
#   [settled] Page 357: fetched 200 events (total: 71400)
#   [settled] Page 358: fetched 200 events (total: 71600)
#   [settled] Page 359: fetched 200 events (total: 71800)
#   [settled] Page 360: fetched 200 events (total: 72000)
#   [settled] Page 361: fetched 200 events (total: 72200)
#   [settled] Page 362: fetched 200 events (total: 72400)
#   [settled] Page 363: fetched 200 events (total: 72600)
#   [settled] Page 364: fetched 200 events (total: 72800)
#   [settled] Page 365: fetched 200 events (total: 73000)
#   [settled] Page 366: fetched 200 events (total: 73200)
#   [settled] Page 367: fetched 200 events (total: 73400)
#   [settled] Page 368: fetched 200 events (total: 73600)
#   [settled] Page 369: fetched 200 events (total: 73800)
#   [settled] Page 370: fetched 200 events (total: 74000)
#   [settled] Page 371: fetched 200 events (total: 74200)
#   [settled] Page 372: fetched 200 events (total: 74400)
#   [settled] Page 373: fetched 200 events (total: 74600)
#   [settled] Page 374: fetched 200 events (total: 74800)
#   [settled] Page 375: fetched 200 events (total: 75000)
#   [settled] Page 376: fetched 200 events (total: 75200)
#   [settled] Page 377: fetched 200 events (total: 75400)
#   [settled] Page 378: fetched 200 events (total: 75600)
#   [settled] Page 379: fetched 200 events (total: 75800)
#   [settled] Page 380: fetched 200 events (total: 76000)
#   [settled] Page 381: fetched 200 events (total: 76200)
#   [settled] Page 382: fetched 200 events (total: 76400)
#   [settled] Page 383: fetched 200 events (total: 76600)
#   [settled] Page 384: fetched 200 events (total: 76800)
#   [settled] Page 385: fetched 200 events (total: 77000)
#   [settled] Page 386: fetched 200 events (total: 77200)
#   [settled] Page 387: fetched 200 events (total: 77400)
#   [settled] Page 388: fetched 200 events (total: 77600)
#   [settled] Page 389: fetched 200 events (total: 77800)
#   [settled] Page 390: fetched 200 events (total: 78000)
#   [settled] Page 391: fetched 200 events (total: 78200)
#   [settled] Page 392: fetched 200 events (total: 78400)
#   [settled] Page 393: fetched 200 events (total: 78600)
#   [settled] Page 394: fetched 200 events (total: 78800)
#   [settled] Page 395: fetched 200 events (total: 79000)
#   [settled] Page 396: fetched 200 events (total: 79200)
#   [settled] Page 397: fetched 200 events (total: 79400)
#   [settled] Page 398: fetched 200 events (total: 79600)
#   [settled] Page 399: fetched 200 events (total: 79800)
#   [settled] Page 400: fetched 200 events (total: 80000)
#   [settled] Page 401: fetched 200 events (total: 80200)
#   [settled] Page 402: fetched 200 events (total: 80400)
#   [settled] Page 403: fetched 200 events (total: 80600)
#   [settled] Page 404: fetched 200 events (total: 80800)
#   [settled] Page 405: fetched 200 events (total: 81000)
#   [settled] Page 406: fetched 200 events (total: 81200)
#   [settled] Page 407: fetched 200 events (total: 81400)
#   [settled] Page 408: fetched 200 events (total: 81600)
#   [settled] Page 409: fetched 200 events (total: 81800)
#   [settled] Page 410: fetched 200 events (total: 82000)
#   [settled] Page 411: fetched 200 events (total: 82200)
#   [settled] Page 412: fetched 200 events (total: 82400)
#   [settled] Page 413: fetched 200 events (total: 82600)
#   [settled] Page 414: fetched 200 events (total: 82800)
#   [settled] Page 415: fetched 200 events (total: 83000)
#   [settled] Page 416: fetched 200 events (total: 83200)
#   [settled] Page 417: fetched 200 events (total: 83400)
#   [settled] Page 418: fetched 200 events (total: 83600)
#   [settled] Page 419: fetched 200 events (total: 83800)
#   [settled] Page 420: fetched 200 events (total: 84000)
#   [settled] Page 421: fetched 200 events (total: 84200)
#   [settled] Page 422: fetched 200 events (total: 84400)
#   [settled] Page 423: fetched 200 events (total: 84600)
#   [settled] Page 424: fetched 200 events (total: 84800)
#   [settled] Page 425: fetched 200 events (total: 85000)
#   [settled] Page 426: fetched 200 events (total: 85200)
#   [settled] Page 427: fetched 200 events (total: 85400)
#   [settled] Page 428: fetched 200 events (total: 85600)
#   [settled] Page 429: fetched 200 events (total: 85800)
#   [settled] Page 430: fetched 200 events (total: 86000)
#   [settled] Page 431: fetched 200 events (total: 86200)
#   [settled] Page 432: fetched 200 events (total: 86400)
#   [settled] Page 433: fetched 200 events (total: 86600)
#   [settled] Page 434: fetched 200 events (total: 86800)
#   [settled] Page 435: fetched 200 events (total: 87000)
#   [settled] Page 436: fetched 200 events (total: 87200)
#   [settled] Page 437: fetched 200 events (total: 87400)
#   [settled] Page 438: fetched 200 events (total: 87600)
#   [settled] Page 439: fetched 200 events (total: 87800)
#   [settled] Page 440: fetched 200 events (total: 88000)
#   [settled] Page 441: fetched 200 events (total: 88200)
#   [settled] Page 442: fetched 200 events (total: 88400)
#   [settled] Page 443: fetched 200 events (total: 88600)
#   [settled] Page 444: fetched 200 events (total: 88800)
#   [settled] Page 445: fetched 200 events (total: 89000)
#   [settled] Page 446: fetched 200 events (total: 89200)
#   [settled] Page 447: fetched 200 events (total: 89400)
#   [settled] Page 448: fetched 200 events (total: 89600)
#   [settled] Page 449: fetched 200 events (total: 89800)
#   [settled] Page 450: fetched 200 events (total: 90000)
#   [settled] Page 451: fetched 200 events (total: 90200)
#   [settled] Page 452: fetched 200 events (total: 90400)
#   [settled] Page 453: fetched 200 events (total: 90600)
#   [settled] Page 454: fetched 200 events (total: 90800)
#   [settled] Page 455: fetched 200 events (total: 91000)
#   [settled] Page 456: fetched 200 events (total: 91200)
#   [settled] Page 457: fetched 200 events (total: 91400)
#   [settled] Page 458: fetched 200 events (total: 91600)
#   [settled] Page 459: fetched 200 events (total: 91800)
#   [settled] Page 460: fetched 200 events (total: 92000)
#   [settled] Page 461: fetched 200 events (total: 92200)
#   [settled] Page 462: fetched 200 events (total: 92400)
#   [settled] Page 463: fetched 200 events (total: 92600)
#   [settled] Page 464: fetched 200 events (total: 92800)
#   [settled] Page 465: fetched 200 events (total: 93000)
#   [settled] Page 466: fetched 200 events (total: 93200)
#   [settled] Page 467: fetched 200 events (total: 93400)
#   [settled] Page 468: fetched 200 events (total: 93600)
#   [settled] Page 469: fetched 200 events (total: 93800)
#   [settled] Page 470: fetched 200 events (total: 94000)
#   [settled] Page 471: fetched 200 events (total: 94200)
#   [settled] Page 472: fetched 200 events (total: 94400)
#   [settled] Page 473: fetched 200 events (total: 94600)
#   [settled] Page 474: fetched 200 events (total: 94800)
#   [settled] Page 475: fetched 200 events (total: 95000)
#   [settled] Page 476: fetched 200 events (total: 95200)
#   [settled] Page 477: fetched 200 events (total: 95400)
#   [settled] Page 478: fetched 200 events (total: 95600)
#   [settled] Page 479: fetched 200 events (total: 95800)
#   [settled] Page 480: fetched 200 events (total: 96000)
#   [settled] Page 481: fetched 200 events (total: 96200)
#   [settled] Page 482: fetched 200 events (total: 96400)
#   [settled] Page 483: fetched 200 events (total: 96600)
#   [settled] Page 484: fetched 200 events (total: 96800)
#   [settled] Page 485: fetched 200 events (total: 97000)
#   [settled] Page 486: fetched 200 events (total: 97200)
#   [settled] Page 487: fetched 200 events (total: 97400)
#   [settled] Page 488: fetched 200 events (total: 97600)
#   [settled] Page 489: fetched 200 events (total: 97800)
#   [settled] Page 490: fetched 200 events (total: 98000)
#   [settled] Page 491: fetched 200 events (total: 98200)
#   [settled] Page 492: fetched 200 events (total: 98400)
#   [settled] Page 493: fetched 200 events (total: 98600)
#   [settled] Page 494: fetched 200 events (total: 98800)
#   [settled] Page 495: fetched 200 events (total: 99000)
#   [settled] Page 496: fetched 200 events (total: 99200)
#   [settled] Page 497: fetched 200 events (total: 99400)
#   [settled] Page 498: fetched 200 events (total: 99600)
#   [settled] Page 499: fetched 200 events (total: 99800)
#   [settled] Page 500: fetched 200 events (total: 100000)
#   [settled] Page 501: fetched 200 events (total: 100200)
#   [settled] Page 502: fetched 200 events (total: 100400)
#   [settled] Page 503: fetched 200 events (total: 100600)
#   [settled] Page 504: fetched 200 events (total: 100800)
#   [settled] Page 505: fetched 200 events (total: 101000)
#   [settled] Page 506: fetched 200 events (total: 101200)
#   [settled] Page 507: fetched 200 events (total: 101400)
#   [settled] Page 508: fetched 200 events (total: 101600)
#   [settled] Page 509: fetched 200 events (total: 101800)
#   [settled] Page 510: fetched 200 events (total: 102000)
#   [settled] Page 511: fetched 200 events (total: 102200)
#   [settled] Page 512: fetched 200 events (total: 102400)
#   [settled] Page 513: fetched 200 events (total: 102600)
#   [settled] Page 514: fetched 200 events (total: 102800)
#   [settled] Page 515: fetched 200 events (total: 103000)
#   [settled] Page 516: fetched 200 events (total: 103200)
#   [settled] Page 517: fetched 200 events (total: 103400)
#   [settled] Page 518: fetched 200 events (total: 103600)
#   [settled] Page 519: fetched 200 events (total: 103800)
#   [settled] Page 520: fetched 200 events (total: 104000)
#   [settled] Page 521: fetched 200 events (total: 104200)
#   [settled] Page 522: fetched 200 events (total: 104400)
#   [settled] Page 523: fetched 200 events (total: 104600)
#   [settled] Page 524: fetched 200 events (total: 104800)
#   [settled] Page 525: fetched 200 events (total: 105000)
#   [settled] Page 526: fetched 200 events (total: 105200)
#   [settled] Page 527: fetched 200 events (total: 105400)
#   [settled] Page 528: fetched 200 events (total: 105600)
#   [settled] Page 529: fetched 200 events (total: 105800)
#   [settled] Page 530: fetched 200 events (total: 106000)
#   [settled] Page 531: fetched 200 events (total: 106200)
#   [settled] Page 532: fetched 200 events (total: 106400)
#   [settled] Page 533: fetched 200 events (total: 106600)
#   [settled] Page 534: fetched 200 events (total: 106800)
#   [settled] Page 535: fetched 200 events (total: 107000)
#   [settled] Page 536: fetched 200 events (total: 107200)
#   [settled] Page 537: fetched 200 events (total: 107400)
#   [settled] Page 538: fetched 200 events (total: 107600)
#   [settled] Page 539: fetched 200 events (total: 107800)
#   [settled] Page 540: fetched 200 events (total: 108000)
#   [settled] Page 541: fetched 200 events (total: 108200)
#   [settled] Page 542: fetched 200 events (total: 108400)
#   [settled] Page 543: fetched 200 events (total: 108600)
#   [settled] Page 544: fetched 200 events (total: 108800)
#   [settled] Page 545: fetched 200 events (total: 109000)
#   [settled] Page 546: fetched 200 events (total: 109200)
#   [settled] Page 547: fetched 200 events (total: 109400)
#   [settled] Page 548: fetched 200 events (total: 109600)
#   [settled] Page 549: fetched 200 events (total: 109800)
#   [settled] Page 550: fetched 200 events (total: 110000)
#   [settled] Page 551: fetched 200 events (total: 110200)
#   [settled] Page 552: fetched 200 events (total: 110400)
#   [settled] Page 553: fetched 200 events (total: 110600)
#   [settled] Page 554: fetched 200 events (total: 110800)
#   [settled] Page 555: fetched 200 events (total: 111000)
#   [settled] Page 556: fetched 200 events (total: 111200)
#   [settled] Page 557: fetched 200 events (total: 111400)
#   [settled] Page 558: fetched 200 events (total: 111600)
#   [settled] Page 559: fetched 200 events (total: 111800)
#   [settled] Page 560: fetched 200 events (total: 112000)
#   [settled] Page 561: fetched 200 events (total: 112200)
#   [settled] Page 562: fetched 200 events (total: 112400)
#   [settled] Page 563: fetched 200 events (total: 112600)
#   [settled] Page 564: fetched 200 events (total: 112800)
#   [settled] Page 565: fetched 200 events (total: 113000)
#   [settled] Page 566: fetched 200 events (total: 113200)
#   [settled] Page 567: fetched 200 events (total: 113400)
#   [settled] Page 568: fetched 200 events (total: 113600)
#   [settled] Page 569: fetched 200 events (total: 113800)
#   [settled] Page 570: fetched 200 events (total: 114000)
#   [settled] Page 571: fetched 200 events (total: 114200)
#   [settled] Page 572: fetched 200 events (total: 114400)
#   [settled] Page 573: fetched 200 events (total: 114600)
#   [settled] Page 574: fetched 200 events (total: 114800)
#   [settled] Page 575: fetched 200 events (total: 115000)
#   [settled] Page 576: fetched 200 events (total: 115200)
#   [settled] Page 577: fetched 200 events (total: 115400)
#   [settled] Page 578: fetched 200 events (total: 115600)
#   [settled] Page 579: fetched 200 events (total: 115800)
#   [settled] Page 580: fetched 200 events (total: 116000)
#   [settled] Page 581: fetched 200 events (total: 116200)
#   [settled] Page 582: fetched 200 events (total: 116400)
#   [settled] Page 583: fetched 200 events (total: 116600)
#   [settled] Page 584: fetched 200 events (total: 116800)
#   [settled] Page 585: fetched 200 events (total: 117000)
#   [settled] Page 586: fetched 200 events (total: 117200)
#   [settled] Page 587: fetched 200 events (total: 117400)
#   [settled] Page 588: fetched 200 events (total: 117600)
#   [settled] Page 589: fetched 200 events (total: 117800)
#   [settled] Page 590: fetched 200 events (total: 118000)
#   [settled] Page 591: fetched 200 events (total: 118200)
#   [settled] Page 592: fetched 200 events (total: 118400)
#   [settled] Page 593: fetched 200 events (total: 118600)
#   [settled] Page 594: fetched 200 events (total: 118800)
#   [settled] Page 595: fetched 200 events (total: 119000)
#   [settled] Page 596: fetched 200 events (total: 119200)
#   [settled] Page 597: fetched 200 events (total: 119400)
#   [settled] Page 598: fetched 200 events (total: 119600)
#   [settled] Page 599: fetched 200 events (total: 119800)
#   [settled] Page 600: fetched 200 events (total: 120000)
#   [settled] Page 601: fetched 200 events (total: 120200)
#   [settled] Page 602: fetched 200 events (total: 120400)
#   [settled] Page 603: fetched 200 events (total: 120600)
#   [settled] Page 604: fetched 200 events (total: 120800)
#   [settled] Page 605: fetched 200 events (total: 121000)
#   [settled] Page 606: fetched 200 events (total: 121200)
#   [settled] Page 607: fetched 200 events (total: 121400)
#   [settled] Page 608: fetched 200 events (total: 121600)
#   [settled] Page 609: fetched 200 events (total: 121800)
#   [settled] Page 610: fetched 200 events (total: 122000)
#   [settled] Page 611: fetched 200 events (total: 122200)
#   [settled] Page 612: fetched 200 events (total: 122400)
#   [settled] Page 613: fetched 200 events (total: 122600)
#   [settled] Page 614: fetched 200 events (total: 122800)
#   [settled] Page 615: fetched 200 events (total: 123000)
#   [settled] Page 616: fetched 200 events (total: 123200)
#   [settled] Page 617: fetched 200 events (total: 123400)
#   [settled] Page 618: fetched 200 events (total: 123600)
#   [settled] Page 619: fetched 200 events (total: 123800)
#   [settled] Page 620: fetched 200 events (total: 124000)
#   [settled] Page 621: fetched 200 events (total: 124200)
#   [settled] Page 622: fetched 200 events (total: 124400)
#   [settled] Page 623: fetched 200 events (total: 124600)
#   [settled] Page 624: fetched 200 events (total: 124800)
#   [settled] Page 625: fetched 200 events (total: 125000)
#   [settled] Page 626: fetched 200 events (total: 125200)
#   [settled] Page 627: fetched 200 events (total: 125400)
#   [settled] Page 628: fetched 200 events (total: 125600)
#   [settled] Page 629: fetched 200 events (total: 125800)
#   [settled] Page 630: fetched 200 events (total: 126000)
#   [settled] Page 631: fetched 200 events (total: 126200)
#   [settled] Page 632: fetched 200 events (total: 126400)
#   [settled] Page 633: fetched 200 events (total: 126600)
#   [settled] Page 634: fetched 200 events (total: 126800)
#   [settled] Page 635: fetched 200 events (total: 127000)
#   [settled] Page 636: fetched 200 events (total: 127200)
#   [settled] Page 637: fetched 200 events (total: 127400)
#   [settled] Page 638: fetched 200 events (total: 127600)
#   [settled] Page 639: fetched 200 events (total: 127800)
#   [settled] Page 640: fetched 200 events (total: 128000)
#   [settled] Page 641: fetched 200 events (total: 128200)
#   [settled] Page 642: fetched 200 events (total: 128400)
#   [settled] Page 643: fetched 200 events (total: 128600)
#   [settled] Page 644: fetched 200 events (total: 128800)
#   [settled] Page 645: fetched 200 events (total: 129000)
#   [settled] Page 646: fetched 200 events (total: 129200)
#   [settled] Page 647: fetched 200 events (total: 129400)
#   [settled] Page 648: fetched 200 events (total: 129600)
#   [settled] Page 649: fetched 200 events (total: 129800)
#   [settled] Page 650: fetched 200 events (total: 130000)
#   [settled] Page 651: fetched 200 events (total: 130200)
#   [settled] Page 652: fetched 200 events (total: 130400)
#   [settled] Page 653: fetched 200 events (total: 130600)
#   [settled] Page 654: fetched 200 events (total: 130800)
#   [settled] Page 655: fetched 200 events (total: 131000)
#   [settled] Page 656: fetched 200 events (total: 131200)
#   [settled] Page 657: fetched 200 events (total: 131400)
#   [settled] Page 658: fetched 200 events (total: 131600)
#   [settled] Page 659: fetched 200 events (total: 131800)
#   [settled] Page 660: fetched 200 events (total: 132000)
#   [settled] Page 661: fetched 200 events (total: 132200)
#   [settled] Page 662: fetched 200 events (total: 132400)
#   [settled] Page 663: fetched 200 events (total: 132600)
#   [settled] Page 664: fetched 200 events (total: 132800)
#   [settled] Page 665: fetched 200 events (total: 133000)
#   [settled] Page 666: fetched 200 events (total: 133200)
#   [settled] Page 667: fetched 200 events (total: 133400)
#   [settled] Page 668: fetched 200 events (total: 133600)
#   [settled] Page 669: fetched 200 events (total: 133800)
#   [settled] Page 670: fetched 200 events (total: 134000)
#   [settled] Page 671: fetched 200 events (total: 134200)
#   [settled] Page 672: fetched 200 events (total: 134400)
#   [settled] Page 673: fetched 200 events (total: 134600)
#   [settled] Page 674: fetched 200 events (total: 134800)
#   [settled] Page 675: fetched 200 events (total: 135000)
#   [settled] Page 676: fetched 200 events (total: 135200)
#   [settled] Page 677: fetched 200 events (total: 135400)
#   [settled] Page 678: fetched 200 events (total: 135600)
#   [settled] Page 679: fetched 200 events (total: 135800)
#   [settled] Page 680: fetched 200 events (total: 136000)
#   [settled] Page 681: fetched 200 events (total: 136200)
#   [settled] Page 682: fetched 200 events (total: 136400)
#   [settled] Page 683: fetched 200 events (total: 136600)
#   [settled] Page 684: fetched 200 events (total: 136800)
#   [settled] Page 685: fetched 200 events (total: 137000)
#   [settled] Page 686: fetched 200 events (total: 137200)
#   [settled] Page 687: fetched 200 events (total: 137400)
#   [settled] Page 688: fetched 200 events (total: 137600)
#   [settled] Page 689: fetched 200 events (total: 137800)
#   [settled] Page 690: fetched 200 events (total: 138000)
#   [settled] Page 691: fetched 200 events (total: 138200)
#   [settled] Page 692: fetched 200 events (total: 138400)
#   [settled] Page 693: fetched 200 events (total: 138600)
#   [settled] Page 694: fetched 200 events (total: 138800)
#   [settled] Page 695: fetched 200 events (total: 139000)
#   [settled] Page 696: fetched 200 events (total: 139200)
#   [settled] Page 697: fetched 200 events (total: 139400)
#   [settled] Page 698: fetched 200 events (total: 139600)
#   [settled] Page 699: fetched 200 events (total: 139800)
#   [settled] Page 700: fetched 200 events (total: 140000)
#   [settled] Page 701: fetched 200 events (total: 140200)
#   [settled] Page 702: fetched 200 events (total: 140400)
#   [settled] Page 703: fetched 200 events (total: 140600)
#   [settled] Page 704: fetched 200 events (total: 140800)
#   [settled] Page 705: fetched 200 events (total: 141000)
#   [settled] Page 706: fetched 200 events (total: 141200)
#   [settled] Page 707: fetched 200 events (total: 141400)
#   [settled] Page 708: fetched 200 events (total: 141600)
#   [settled] Page 709: fetched 200 events (total: 141800)
#   [settled] Page 710: fetched 200 events (total: 142000)
#   [settled] Page 711: fetched 200 events (total: 142200)
#   [settled] Page 712: fetched 200 events (total: 142400)
#   [settled] Page 713: fetched 200 events (total: 142600)
#   [settled] Page 714: fetched 200 events (total: 142800)
#   [settled] Page 715: fetched 200 events (total: 143000)
#   [settled] Page 716: fetched 200 events (total: 143200)
#   [settled] Page 717: fetched 200 events (total: 143400)
#   [settled] Page 718: fetched 200 events (total: 143600)
#   [settled] Page 719: fetched 200 events (total: 143800)
#   [settled] Page 720: fetched 200 events (total: 144000)
#   [settled] Page 721: fetched 200 events (total: 144200)
#   [settled] Page 722: fetched 200 events (total: 144400)
#   [settled] Page 723: fetched 200 events (total: 144600)
#   [settled] Page 724: fetched 200 events (total: 144800)
#   [settled] Page 725: fetched 200 events (total: 145000)
#   [settled] Page 726: fetched 200 events (total: 145200)
#   [settled] Page 727: fetched 200 events (total: 145400)
#   [settled] Page 728: fetched 200 events (total: 145600)
#   [settled] Page 729: fetched 200 events (total: 145800)
#   [settled] Page 730: fetched 200 events (total: 146000)
#   [settled] Page 731: fetched 200 events (total: 146200)
#   [settled] Page 732: fetched 200 events (total: 146400)
#   [settled] Page 733: fetched 200 events (total: 146600)
#   [settled] Page 734: fetched 200 events (total: 146800)
#   [settled] Page 735: fetched 200 events (total: 147000)
#   [settled] Page 736: fetched 200 events (total: 147200)
#   [settled] Page 737: fetched 200 events (total: 147400)
#   [settled] Page 738: fetched 200 events (total: 147600)
#   [settled] Page 739: fetched 200 events (total: 147800)
#   [settled] Page 740: fetched 200 events (total: 148000)
#   [settled] Page 741: fetched 200 events (total: 148200)
#   [settled] Page 742: fetched 200 events (total: 148400)
#   [settled] Page 743: fetched 200 events (total: 148600)
#   [settled] Page 744: fetched 200 events (total: 148800)
#   [settled] Page 745: fetched 200 events (total: 149000)
#   [settled] Page 746: fetched 200 events (total: 149200)
#   [settled] Page 747: fetched 115 events (total: 149315)
#   [settled] Complete: 149315 events
# --------------------------------------------------
# Total events scraped: 153900
# Saved 153900 events to kalshi_events_20260210_195805.csv
#
# ==================================================
# SUMMARY BY CATEGORY
# ==================================================
#   Crypto: 55102
#   Sports: 52929
#   Financials: 18664
#   Climate and Weather: 12975
#   Entertainment: 5885
#   Politics: 2765
#   Economics: 1617
#   Elections: 1017
#   Mentions: 825
#   Health: 525
#   Transportation: 509
#   Companies: 423
#   Science and Technology: 292
#   World: 260
#   Social: 109
#   Education: 2
#   COVID-19: 1
#
# ==================================================
# SUMMARY BY STATUS
# ==================================================
#   settled: 149315
#   open: 4132
#   closed: 453
#
# Done! Output: kalshi_events_20260210_195805.csv

# %%
"""
Kalshi Events Scraper
Pulls all open and closed events using multi-threading and saves to CSV.
Supports filtering by minimum volume (contracts) or dollar volume.

Usage:
    python kalshi_scraper.py                              # All events
    python kalshi_scraper.py --min-volume 1000            # Events with 1000+ contracts
    python kalshi_scraper.py --min-dollar-volume 1000000  # Events with $1M+ dollar volume
    python kalshi_scraper.py --min-dollar-volume 1000000 --status closed  # Closed $1M+ events
    
Output:
    kalshi_events_YYYYMMDD_HHMMSS.csv
    
Note:
    Dollar volume is estimated as sum(volume * last_price) across all markets.
    If no price data is available, assumes $0.50 per contract.
"""

import argparse
import requests
import csv
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

BASE_URL = "https://api.elections.kalshi.com/trade-api/v2/events"

def get_session() -> requests.Session:
    """Create a session with retry logic."""
    session = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.5,
        status_forcelist=[429, 500, 502, 503, 504]
    )
    adapter = HTTPAdapter(max_retries=retries)
    session.mount("https://", adapter)
    return session

def fetch_events_page(session: requests.Session, status: str = None, cursor: str = None) -> dict:
    """Fetch a single page of events with nested market data."""
    params = {
        "limit": 200,
        "with_nested_markets": "true"  # Include market data for volume calculation
    }
    if status:
        params["status"] = status
    if cursor:
        params["cursor"] = cursor
    
    response = session.get(BASE_URL, params=params, timeout=30)
    response.raise_for_status()
    return response.json()

def calculate_event_volume(event: dict) -> int:
    """Calculate total volume (contracts) across all markets in an event."""
    markets = event.get("markets", [])
    return sum(m.get("volume", 0) for m in markets)

def calculate_event_dollar_volume(event: dict) -> float:
    """
    Estimate dollar volume across all markets in an event.
    
    Dollar volume = sum of (volume * last_price) for each market.
    Prices are in cents, so we divide by 100 to get dollars.
    
    Falls back to volume * 0.50 if no price data available.
    """
    markets = event.get("markets", [])
    total_dollar_volume = 0.0
    
    for m in markets:
        volume = m.get("volume", 0)
        # last_price is in cents (0-100)
        last_price = m.get("last_price", 50)  # Default to 50 cents if no price
        if last_price == 0:
            last_price = 50  # Assume 50 cents for markets with no trades
        
        # Convert cents to dollars and multiply by volume
        dollar_volume = volume * (last_price / 100.0)
        total_dollar_volume += dollar_volume
    
    return total_dollar_volume

def calculate_event_open_interest(event: dict) -> int:
    """Calculate total open interest across all markets in an event."""
    markets = event.get("markets", [])
    return sum(m.get("open_interest", 0) for m in markets)

def get_event_close_time(event: dict) -> str:
    """Get the latest close time from markets in an event."""
    markets = event.get("markets", [])
    close_times = [m.get("close_time", "") for m in markets if m.get("close_time")]
    return max(close_times) if close_times else ""

def get_market_count(event: dict) -> int:
    """Get the number of markets in an event."""
    return len(event.get("markets", []))

def fetch_all_events_for_status(status: str = None, min_volume: int = 0, min_dollar_volume: float = 0) -> list:
    """Fetch all events for a given status (handles pagination). If status is None, fetches all."""
    session = get_session()
    all_events = []
    cursor = None
    page = 0
    label = status if status else "all"
    filtered_count = 0
    
    while True:
        page += 1
        data = fetch_events_page(session, status, cursor)
        events = data.get("events", [])
        
        if not events:
            break
        
        for event in events:
            # Calculate aggregate stats from nested markets
            total_volume = calculate_event_volume(event)
            total_dollar_volume = calculate_event_dollar_volume(event)
            
            # Apply volume filters
            if total_volume < min_volume:
                filtered_count += 1
                continue
            if total_dollar_volume < min_dollar_volume:
                filtered_count += 1
                continue
            
            # Enrich event with computed fields
            event["scrape_status"] = label
            event["total_volume"] = total_volume
            event["total_dollar_volume"] = round(total_dollar_volume, 2)
            event["total_open_interest"] = calculate_event_open_interest(event)
            event["close_time"] = get_event_close_time(event)
            event["market_count"] = get_market_count(event)
            
            all_events.append(event)
        
        print(f"  [{label}] Page {page}: processed {len(events)} events, kept {len(all_events)} (filtered {filtered_count})")
        
        cursor = data.get("cursor")
        if not cursor:
            break
        
        # Small delay to be nice to the API
        time.sleep(0.1)
    
    return all_events

def scrape_all_events(statuses: list, min_volume: int = 0, min_dollar_volume: float = 0) -> list:
    """Scrape all events using multi-threading for different statuses."""
    all_events = []
    
    print(f"Starting scrape at {datetime.now().isoformat()}")
    print(f"Filters: statuses={statuses}, min_volume={min_volume:,}, min_dollar_volume=${min_dollar_volume:,.0f}")
    print("-" * 60)
    
    # Fetch different statuses in parallel
    with ThreadPoolExecutor(max_workers=3) as executor:
        future_to_status = {
            executor.submit(fetch_all_events_for_status, status, min_volume, min_dollar_volume): status 
            for status in statuses
        }
        
        for future in as_completed(future_to_status):
            status = future_to_status[future]
            try:
                events = future.result()
                all_events.extend(events)
                print(f"  [{status}] Complete: {len(events)} events")
            except Exception as e:
                print(f"  [{status}] Error: {e}")
    
    # If status filters failed, try fetching all without filter
    if len(all_events) == 0:
        print("\nStatus filters failed. Trying without status filter...")
        try:
            all_events = fetch_all_events_for_status(None, min_volume, min_dollar_volume)
            print(f"  [all] Complete: {len(all_events)} events")
        except Exception as e:
            print(f"  [all] Error: {e}")
    
    print("-" * 60)
    print(f"Total events scraped: {len(all_events)}")
    
    return all_events

def events_to_csv(events: list, filename: str):
    """Save events to CSV file."""
    if not events:
        print("No events to save.")
        return
    
    # Define columns to extract (including computed fields)
    columns = [
        "event_ticker",
        "series_ticker", 
        "title",
        "sub_title",
        "category",
        "mutually_exclusive",
        "total_volume",
        "total_dollar_volume",
        "total_open_interest",
        "market_count",
        "close_time",
        "scrape_status",
        "available_on_brokers",
        "collateral_return_type",
        "strike_period",
    ]
    
    with open(filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=columns, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(events)
    
    print(f"Saved {len(events)} events to {filename}")

def main():
    # Parse command line arguments
    parser = argparse.ArgumentParser(description="Scrape Kalshi events to CSV")
    parser.add_argument(
        "--min-volume", 
        type=int, 
        default=0,
        help="Minimum total contracts traded across all markets in an event (default: 0)"
    )
    parser.add_argument(
        "--min-dollar-volume",
        type=float,
        default=0,
        help="Minimum estimated dollar volume in USD (default: 0). Use 1000000 for $1M+"
    )
    parser.add_argument(
        "--status",
        type=str,
        nargs="+",
        default=["open", "closed", "settled"],
        choices=["open", "closed", "settled"],
        help="Event statuses to fetch (default: open closed settled)"
    )
    parser.add_argument(
        "--output",
        type=str,
        default=None,
        help="Output filename (default: kalshi_events_TIMESTAMP.csv)"
    )
    args = parser.parse_args()
    
    # Scrape all events
    events = scrape_all_events(args.status, args.min_volume, args.min_dollar_volume)
    
    # Save to CSV with timestamp
    if args.output:
        filename = args.output
    else:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"kalshi_events_{timestamp}.csv"
    
    events_to_csv(events, filename)
    
    # Print summary by category
    print("\n" + "=" * 60)
    print("SUMMARY BY CATEGORY")
    print("=" * 60)
    
    categories = {}
    for event in events:
        cat = event.get("category", "Unknown")
        categories[cat] = categories.get(cat, 0) + 1
    
    for cat, count in sorted(categories.items(), key=lambda x: -x[1]):
        print(f"  {cat}: {count}")
    
    # Print summary by status
    print("\n" + "=" * 60)
    print("SUMMARY BY STATUS")
    print("=" * 60)
    
    statuses = {}
    for event in events:
        status = event.get("scrape_status", "Unknown")
        statuses[status] = statuses.get(status, 0) + 1
    
    for status, count in sorted(statuses.items(), key=lambda x: -x[1]):
        print(f"  {status}: {count}")
    
    # Print volume stats
    if events:
        volumes = [e.get("total_volume", 0) for e in events]
        dollar_volumes = [e.get("total_dollar_volume", 0) for e in events]
        print("\n" + "=" * 60)
        print("VOLUME STATISTICS")
        print("=" * 60)
        print(f"  Total contracts: {sum(volumes):,}")
        print(f"  Total dollar volume: ${sum(dollar_volumes):,.2f}")
        print(f"  Mean dollar volume: ${sum(dollar_volumes) / len(dollar_volumes):,.2f}")
        print(f"  Max dollar volume: ${max(dollar_volumes):,.2f}")
        print(f"  Min dollar volume: ${min(dollar_volumes):,.2f}")
    
    return filename

if __name__ == "__main__":
    output_file = main()
    print(f"\nDone! Output: {output_file}")
# Out:
# usage: ipykernel_launcher.py [-h] [--min-volume MIN_VOLUME]
#                              [--min-dollar-volume MIN_DOLLAR_VOLUME]
#                              [--status {open,closed,settled} [{open,closed,settled} ...]]
#                              [--output OUTPUT]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/yiyangyu/Library/Jupyter/runtime/kernel-v36cd99daedee8a7535c8edd4f46c2843d017073fb.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# Add this temporarily to see all fields in a market
import requests
url = "https://api.elections.kalshi.com/trade-api/v2/events?limit=1&with_nested_markets=true"
response = requests.get(url)
data = response.json()
if data.get("events"):
    market = data["events"][0].get("markets", [{}])[0]
    print("Available market fields:")
    for key in sorted(market.keys()):
        print(f"  {key}: {market.get(key)}")
# Out:
# Available market fields:
#   can_close_early: True
#   close_time: 2099-08-01T04:59:00Z
#   created_time: 0001-01-01T00:00:00Z
#   early_close_condition: This market will close and expire early if the event occurs.
#   event_ticker: KXELONMARS-99
#   expected_expiration_time: 2099-08-01T15:00:00Z
#   expiration_time: 2099-08-08T15:00:00Z
#   expiration_value:
#   last_price: 8
#   last_price_dollars: 0.0800
#   latest_expiration_time: 2099-08-08T15:00:00Z
#   liquidity: 5883237
#   liquidity_dollars: 58832.3700
#   market_type: binary
#   no_ask: 93
#   no_ask_dollars: 0.9300
#   no_bid: 92
#   no_bid_dollars: 0.9200
#   no_sub_title: Mars
#   notional_value: 100
#   notional_value_dollars: 1.0000
#   open_interest: 15115
#   open_interest_fp: 15115.00
#   open_time: 2025-08-28T20:45:00Z
#   previous_price: 0
#   previous_price_dollars: 0.0000
#   previous_yes_ask: 0
#   previous_yes_ask_dollars: 0.0000
#   previous_yes_bid: 0
#   previous_yes_bid_dollars: 0.0000
#   price_level_structure: linear_cent
#   price_ranges: [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}]
#   response_price_units: usd_cent
#   result:
#   rules_primary: If Elon Musk visits Mars before the earlier of his death or Aug 1, 2099, then the market resolves to Yes.
#   rules_secondary:
#   settlement_timer_seconds: 1800
#   status: active
#   subtitle:
#   tick_size: 1
#   ticker: KXELONMARS-99
#   title: Will Elon Musk visit Mars before Aug 1, 2099?
#   updated_time: 0001-01-01T00:00:00Z
#   volume: 43101
#   volume_24h: 125
#   volume_24h_fp: 125.00
#   volume_fp: 43101.00
#   yes_ask: 8
#   yes_ask_dollars: 0.0800
#   yes_bid: 7
#   yes_bid_dollars: 0.0700
#   yes_sub_title: Mars

# %%
import requests

BASE_URL = "https://api.elections.kalshi.com/trade-api/v2/events"

for status in ["open", "closed", "settled", None]:
    params = {"limit": 200, "with_nested_markets": "true"}
    if status:
        params["status"] = status
    
    response = requests.get(BASE_URL, params=params)
    data = response.json()
    
    events = data.get("events", [])
    cursor = data.get("cursor", "")
    
    label = status if status else "no filter"
    print(f"{label}: {len(events)} events on first page, has_more={bool(cursor)}")
# Out:
# open: 200 events on first page, has_more=True
# closed: 200 events on first page, has_more=True
# settled: 200 events on first page, has_more=True
# no filter: 200 events on first page, has_more=True

# %%
import requests

BASE_URL = "https://api.elections.kalshi.com/trade-api/v2/events"

# Fetch a few pages of closed events and check their volumes
all_volumes = []
cursor = None

for page in range(10):  # Fetch 10 pages = 2000 events
    params = {"limit": 200, "status": "closed", "with_nested_markets": "true"}
    if cursor:
        params["cursor"] = cursor
    
    response = requests.get(BASE_URL, params=params)
    data = response.json()
    
    for event in data.get("events", []):
        markets = event.get("markets", [])
        total_vol = sum(m.get("volume", 0) for m in markets)
        all_volumes.append((event.get("title", "")[:50], total_vol))
    
    cursor = data.get("cursor")
    if not cursor:
        break

# Sort by volume and show top 20
all_volumes.sort(key=lambda x: -x[1])

print(f"Total events checked: {len(all_volumes)}")
print(f"\nTop 20 by dollar volume:")
for i, (title, vol) in enumerate(all_volumes[:20]):
    print(f"  {i+1}. ${vol:>12,}  {title}")

print(f"\nEvents with $1M+: {sum(1 for _, v in all_volumes if v >= 1_000_000)}")
print(f"Events with $500K+: {sum(1 for _, v in all_volumes if v >= 500_000)}")
print(f"Events with $100K+: {sum(1 for _, v in all_volumes if v >= 100_000)}")
# Out:
# Total events checked: 466
#
# Top 20 by dollar volume:
#   1. $   4,780,801  Recession in 2025?
#   2. $     237,398  S&P price on Feb 11, 2026 at 4pm EST?
#   3. $     187,097  Highest temperature in Washington DC on Feb 5, 202
#   4. $     175,675  What will be Odell Beckham Jr.'s next team?
#   5. $     157,952  How much revenue will tariffs bring in in 2025?
#   6. $     116,249  SpaceX Starship launch?
#   7. $      84,146  What will the announcers say during the San Antoni
#   8. $      76,673  January 2026 CPI Combo: CPI & CPI (YoY)
#   9. $      31,056  Who will be the next head coach of New York Pro Me
#   10. $      30,264  S&P price range on Feb 11, 2026 at 4pm EST?
#   11. $      24,701  When will OpenSea launch a token?
#   12. $      24,366  Will another GOP Member of Congress call for Noem'
#   13. $      20,356  How many guinea worm cases will there be this year
#   14. $      20,161  Nasdaq-100 price on Feb 11, 2026 at 4pm EST?
#   15. $      16,364  How much will core PCE increase in Dec 2025?
#   16. $      15,325  When will MegaETH conduct an airdrop?
#   17. $       7,790  Los Angeles C at Sacramento: Triple Doubles
#   18. $       6,657  Treasury 10-year yield on Feb 11, 2026?
#   19. $       6,570  Fulham at Manchester City: Anytime Goalscorer
#   20. $       6,388  Treasury 10-year yield on Jan 27, 2026?
#
# Events with $1M+: 1
# Events with $500K+: 1
# Events with $100K+: 6

# %%
import requests

BASE_URL = "https://api.elections.kalshi.com/trade-api/v2/events"

for status in ["open", "closed", "settled"]:
    all_volumes = []
    cursor = None
    
    while True:
        params = {"limit": 200, "status": status, "with_nested_markets": "true"}
        if cursor:
            params["cursor"] = cursor
        
        response = requests.get(BASE_URL, params=params)
        data = response.json()
        events = data.get("events", [])
        
        if not events:
            break
        
        for event in events:
            markets = event.get("markets", [])
            total_vol = sum(m.get("volume", 0) for m in markets)
            all_volumes.append((event.get("title", "")[:40], total_vol))
        
        cursor = data.get("cursor")
        if not cursor:
            break
    
    # Stats
    over_1m = sum(1 for _, v in all_volumes if v >= 1_000_000)
    over_100k = sum(1 for _, v in all_volumes if v >= 100_000)
    
    print(f"{status:8}: {len(all_volumes):,} events | $1M+: {over_1m} | $100K+: {over_100k}")
    
    # Show top 3 for this status
    all_volumes.sort(key=lambda x: -x[1])
    for title, vol in all_volumes[:3]:
        print(f"          ${vol:>12,}  {title}")
    print()
# Out:
# open    : 4,196 events | $1M+: 88 | $100K+: 432
#           $ 159,220,951  Who will Trump nominate as Fed Chair?
#           $  47,147,405  2028 Democratic nominee for President?
#           $  25,457,230  When will Bitcoin hit $150k?
#
# closed  : 474 events | $1M+: 1 | $100K+: 9
#           $   4,780,801  Recession in 2025?
#           $     305,550  Hapoel Jerusalem vs Reyer Venezia
#           $     237,398  S&P price on Feb 11, 2026 at 4pm EST?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 14
#      11 if cursor:
#      12     params["cursor"] = cursor
# ---> 14 response = requests.get(BASE_URL, params=params)
#      15 data = response.json()
#      16 events = data.get("events", [])
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/urllib3/response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1234 """
#    1235 A generator wrapper for the read() method. A call will block until
#    1236 ``amt`` bytes have been read from the connection or until the
#    (...)   1247     'content-encoding' header.
#    1248 """
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/urllib3/response.py:1421, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1419     if self.chunk_left == 0:
#    1420         break
# -> 1421     chunk = self._handle_chunk(amt)
#    1422 decoded = self._decode(
#    1423     chunk,
#    1424     decode_content=decode_content,
#    1425     flush_decoder=False,
#    1426     max_length=amt,
#    1427 )
#    1428 if decoded:
#
# File ~/Documents/Growth/Python_Playground/KalshiCorrelationForecast/.venv/lib/python3.12/site-packages/urllib3/response.py:1354, in HTTPResponse._handle_chunk(self, amt)
#    1352     self.chunk_left = None
#    1353 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1354     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1355     self.chunk_left = self.chunk_left - amt
#    1356     returned_chunk = value
#
# File /opt/anaconda3/lib/python3.12/http/client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File /opt/anaconda3/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
